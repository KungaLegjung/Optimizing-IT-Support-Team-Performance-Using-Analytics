# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"/Users/kungalegjung/Desktop/Infosys SpringBoard Internship/synthetic_it_support_tickets.csv")
df
# Out:
#          ticket_id           created_at customer_id customer_segment  \
# 0      TCKT_000001  2024-01-31T05:14:27  CUST_00861       individual
# 1      TCKT_000002  2024-10-20T06:15:49  CUST_00770       individual
# 2      TCKT_000003  2024-06-18T21:35:54  CUST_02559   small_business
# 3      TCKT_000004  2025-12-25T15:59:52  CUST_03557        education
# 4      TCKT_000005  2023-08-27T16:08:33  CUST_09556       enterprise
# ...            ...                  ...         ...              ...
# 99995  TCKT_099996  2023-05-16T06:23:50  CUST_06828        education
# 99996  TCKT_099997  2025-03-10T04:46:24  CUST_06621        education
# 99997  TCKT_099998  2025-11-07T19:33:01  CUST_03719       non_profit
# 99998  TCKT_099999  2022-06-20T22:29:10  CUST_02290   small_business
# 99999  TCKT_100000  2022-02-27T14:33:20  CUST_06371        education
#
#                 channel         product_area        issue_type priority  \
# ...

# %%
df.head()
# Out:
#      ticket_id           created_at customer_id customer_segment  \
# 0  TCKT_000001  2024-01-31T05:14:27  CUST_00861       individual
# 1  TCKT_000002  2024-10-20T06:15:49  CUST_00770       individual
# 2  TCKT_000003  2024-06-18T21:35:54  CUST_02559   small_business
# 3  TCKT_000004  2025-12-25T15:59:52  CUST_03557        education
# 4  TCKT_000005  2023-08-27T16:08:33  CUST_09556       enterprise
#
#             channel         product_area        issue_type priority  \
# 0             email          data_export    account_access      low
# 1            in_app              billing  security_concern   medium
# 2              chat      api_integration               bug      low
# 3              chat  analytics_dashboard    account_access   medium
# 4  phone_transcript           login_auth   billing_problem      low
#
#              status  sla_plan  \
# 0          resolved  standard
# 1  closed_no_action  standard
# 2       in_progress  standard
# 3       in_progress  standard
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   ticket_id              100000 non-null  object
#  1   created_at             100000 non-null  object
#  2   customer_id            100000 non-null  object
#  3   customer_segment       100000 non-null  object
#  4   channel                100000 non-null  object
#  5   product_area           100000 non-null  object
#  6   issue_type             100000 non-null  object
#  7   priority               100000 non-null  object
#  8   status                 100000 non-null  object
#  9   sla_plan               100000 non-null  object
#  10  initial_message        100000 non-null  object
#  11  agent_first_reply      100000 non-null  object
#  12  resolution_summary     60113 non-null   object
#  13  resolution_time_hours  60113 non-null   float64
# ...

# %%
df.describe()
# Out:
#        resolution_time_hours       reopened     csat_score  has_attachment
# count           60113.000000  100000.000000  100000.000000   100000.000000
# mean               45.013123       0.050450       2.241950        0.249520
# std                49.202797       0.218873       1.771599        0.432737
# min                 0.110000       0.000000       0.000000        0.000000
# 25%                14.880000       0.000000       0.000000        0.000000
# 50%                29.910000       0.000000       2.000000        0.000000
# 75%                51.660000       0.000000       4.000000        0.000000
# max               239.960000       1.000000       5.000000        1.000000

# %%
df.shape
# Out:
# (100000, 20)

# %%
df.columns
# Out:
# Index(['ticket_id', 'created_at', 'customer_id', 'customer_segment', 'channel',
#        'product_area', 'issue_type', 'priority', 'status', 'sla_plan',
#        'initial_message', 'agent_first_reply', 'resolution_summary',
#        'resolution_time_hours', 'reopened', 'customer_sentiment', 'csat_score',
#        'has_attachment', 'platform', 'region'],
#       dtype='object')

# %%
df["created_at"] = pd.to_datetime(df["created_at"], errors="coerce")

# %%
df.dtypes
# Out:
# ticket_id                        object
# created_at               datetime64[ns]
# customer_id                      object
# customer_segment                 object
# channel                          object
# product_area                     object
# issue_type                       object
# priority                         object
# status                           object
# sla_plan                         object
# initial_message                  object
# agent_first_reply                object
# resolution_summary               object
# resolution_time_hours           float64
# reopened                          int64
# customer_sentiment               object
# csat_score                        int64
# has_attachment                    int64
# platform                         object
# region                           object
# dtype: object

# %%
df.isnull().sum()
# Out:
# ticket_id                    0
# created_at                   0
# customer_id                  0
# customer_segment             0
# channel                      0
# product_area                 0
# issue_type                   0
# priority                     0
# status                       0
# sla_plan                     0
# initial_message              0
# agent_first_reply            0
# resolution_summary       39887
# resolution_time_hours    39887
# reopened                     0
# customer_sentiment           0
# csat_score                   0
# has_attachment               0
# platform                     0
# region                   19997
# dtype: int64

# %%
df["resolution_time_hours"].fillna(
    df["resolution_time_hours"].median(), inplace=True
)
# Out:
# /var/folders/22/9rlp1p9s37bbmyh4xc20j0_m0000gn/T/ipykernel_2405/2364623448.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["resolution_time_hours"].fillna(

# %%
df["region"].fillna("Unknown", inplace=True)
# Out:
# /var/folders/22/9rlp1p9s37bbmyh4xc20j0_m0000gn/T/ipykernel_2405/3992836350.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["region"].fillna("Unknown", inplace=True)

# %%
df = df.copy()

# %%
df.drop(
    columns=[
        "initial_message",
        "agent_first_reply",
        "resolution_summary"
    ],
    inplace=True
)

# %%
df["reopened"] = df["reopened"].astype(bool)
df["has_attachment"] = df["has_attachment"].astype(bool)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   ticket_id              100000 non-null  object
#  1   created_at             100000 non-null  datetime64[ns]
#  2   customer_id            100000 non-null  object
#  3   customer_segment       100000 non-null  object
#  4   channel                100000 non-null  object
#  5   product_area           100000 non-null  object
#  6   issue_type             100000 non-null  object
#  7   priority               100000 non-null  object
#  8   status                 100000 non-null  object
#  9   sla_plan               100000 non-null  object
#  10  resolution_time_hours  100000 non-null  float64
#  11  reopened               100000 non-null  bool
#  12  customer_sentiment     100000 non-null  object
#  13  csat_score             100000 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# ticket_id                0
# created_at               0
# customer_id              0
# customer_segment         0
# channel                  0
# product_area             0
# issue_type               0
# priority                 0
# status                   0
# sla_plan                 0
# resolution_time_hours    0
# reopened                 0
# customer_sentiment       0
# csat_score               0
# has_attachment           0
# platform                 0
# region                   0
# dtype: int64

# %%
df
# Out:
#          ticket_id          created_at customer_id customer_segment  \
# 0      TCKT_000001 2024-01-31 05:14:27  CUST_00861       individual
# 1      TCKT_000002 2024-10-20 06:15:49  CUST_00770       individual
# 2      TCKT_000003 2024-06-18 21:35:54  CUST_02559   small_business
# 3      TCKT_000004 2025-12-25 15:59:52  CUST_03557        education
# 4      TCKT_000005 2023-08-27 16:08:33  CUST_09556       enterprise
# ...            ...                 ...         ...              ...
# 99995  TCKT_099996 2023-05-16 06:23:50  CUST_06828        education
# 99996  TCKT_099997 2025-03-10 04:46:24  CUST_06621        education
# 99997  TCKT_099998 2025-11-07 19:33:01  CUST_03719       non_profit
# 99998  TCKT_099999 2022-06-20 22:29:10  CUST_02290   small_business
# 99999  TCKT_100000 2022-02-27 14:33:20  CUST_06371        education
#
#                 channel         product_area        issue_type priority  \
# 0                 email          data_export    account_access      low
# ...

# %%
df["year"] = df["created_at"].dt.year
df["month"] = df["created_at"].dt.month
df["month_name"] = df["created_at"].dt.month_name()
df["day"] = df["created_at"].dt.day

# %%
df["resolution_time_hours"].fillna(
    df["resolution_time_hours"].median(), inplace=True
)
# Out:
# /var/folders/22/9rlp1p9s37bbmyh4xc20j0_m0000gn/T/ipykernel_2405/2364623448.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["resolution_time_hours"].fillna(

# %%
df["region"].fillna("Unknown", inplace=True)
# Out:
# /var/folders/22/9rlp1p9s37bbmyh4xc20j0_m0000gn/T/ipykernel_2405/3992836350.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["region"].fillna("Unknown", inplace=True)

# %%
df["reopened"] = df["reopened"].map({0: "No", 1: "Yes"})
df["has_attachment"] = df["has_attachment"].map({0: "No", 1: "Yes"})

# %%
categorical_cols = [
    "customer_segment", "channel", "product_area",
    "issue_type", "priority", "status",
    "sla_plan", "customer_sentiment",
    "platform", "region"
]

for col in categorical_cols:
    df[col] = df[col].str.strip().str.title()

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   ticket_id              100000 non-null  object
#  1   created_at             100000 non-null  datetime64[ns]
#  2   customer_id            100000 non-null  object
#  3   customer_segment       100000 non-null  object
#  4   channel                100000 non-null  object
#  5   product_area           100000 non-null  object
#  6   issue_type             100000 non-null  object
#  7   priority               100000 non-null  object
#  8   status                 100000 non-null  object
#  9   sla_plan               100000 non-null  object
#  10  resolution_time_hours  100000 non-null  float64
#  11  reopened               0 non-null       object
#  12  customer_sentiment     100000 non-null  object
#  13  csat_score             100000 non-null  int64
# ...

# %%
df
# Out:
#          ticket_id          created_at customer_id customer_segment  \
# 0      TCKT_000001 2024-01-31 05:14:27  CUST_00861       Individual
# 1      TCKT_000002 2024-10-20 06:15:49  CUST_00770       Individual
# 2      TCKT_000003 2024-06-18 21:35:54  CUST_02559   Small_Business
# 3      TCKT_000004 2025-12-25 15:59:52  CUST_03557        Education
# 4      TCKT_000005 2023-08-27 16:08:33  CUST_09556       Enterprise
# ...            ...                 ...         ...              ...
# 99995  TCKT_099996 2023-05-16 06:23:50  CUST_06828        Education
# 99996  TCKT_099997 2025-03-10 04:46:24  CUST_06621        Education
# 99997  TCKT_099998 2025-11-07 19:33:01  CUST_03719       Non_Profit
# 99998  TCKT_099999 2022-06-20 22:29:10  CUST_02290   Small_Business
# 99999  TCKT_100000 2022-02-27 14:33:20  CUST_06371        Education
#
#                 channel         product_area        issue_type priority  \
# 0                 Email          Data_Export    Account_Access      Low
# ...

# %%
df[["reopened", "has_attachment"]].isnull().sum()
# Out:
# reopened          100000
# has_attachment    100000
# dtype: int64

# %%
df = df.dropna(axis=1, how="all")

# %%
df
# Out:
#          ticket_id          created_at customer_id customer_segment  \
# 0      TCKT_000001 2024-01-31 05:14:27  CUST_00861       Individual
# 1      TCKT_000002 2024-10-20 06:15:49  CUST_00770       Individual
# 2      TCKT_000003 2024-06-18 21:35:54  CUST_02559   Small_Business
# 3      TCKT_000004 2025-12-25 15:59:52  CUST_03557        Education
# 4      TCKT_000005 2023-08-27 16:08:33  CUST_09556       Enterprise
# ...            ...                 ...         ...              ...
# 99995  TCKT_099996 2023-05-16 06:23:50  CUST_06828        Education
# 99996  TCKT_099997 2025-03-10 04:46:24  CUST_06621        Education
# 99997  TCKT_099998 2025-11-07 19:33:01  CUST_03719       Non_Profit
# 99998  TCKT_099999 2022-06-20 22:29:10  CUST_02290   Small_Business
# 99999  TCKT_100000 2022-02-27 14:33:20  CUST_06371        Education
#
#                 channel         product_area        issue_type priority  \
# 0                 Email          Data_Export    Account_Access      Low
# ...

# %%
df.columns
# Out:
# Index(['ticket_id', 'created_at', 'customer_id', 'customer_segment', 'channel',
#        'product_area', 'issue_type', 'priority', 'status', 'sla_plan',
#        'resolution_time_hours', 'customer_sentiment', 'csat_score', 'platform',
#        'region', 'year', 'month', 'month_name', 'day'],
#       dtype='object')

# %%
total_tickets = df.shape[0]
total_tickets
# Out:
# 100000

# %%
tickets_by_month = df.groupby(
    df["created_at"].dt.to_period("M")
).size()
tickets_by_month
# Out:
# created_at
# 2022-01    2109
# 2022-02    1835
# 2022-03    2139
# 2022-04    2044
# 2022-05    2044
# 2022-06    2092
# 2022-07    2070
# 2022-08    2091
# 2022-09    2006
# 2022-10    2094
# 2022-11    2056
# 2022-12    2023
# 2023-01    2068
# 2023-02    1978
# 2023-03    2148
# 2023-04    2039
# 2023-05    2066
# 2023-06    2038
# 2023-07    2263
# 2023-08    2098
# 2023-09    2104
# 2023-10    2121
# 2023-11    2045
# 2023-12    2197
# 2024-01    2161
# 2024-02    1976
# 2024-03    2102
# 2024-04    2078
# 2024-05    2159
# 2024-06    2027
# 2024-07    2114
# 2024-08    2211
# 2024-09    2001
# 2024-10    2097
# 2024-11    2060
# 2024-12    2084
# 2025-01    2158
# 2025-02    1895
# 2025-03    2129
# 2025-04    2058
# 2025-05    2125
# 2025-06    2090
# 2025-07    2127
# 2025-08    2128
# 2025-09    2063
# 2025-10    2146
# 2025-11    2114
# 2025-12    2129
# Freq: M, dtype: int64

# %%
tickets_by_month.plot(title="Tickets Over Time")
# Out:
# <Axes: title={'center': 'Tickets Over Time'}, xlabel='created_at'>

# %%
df["status"].value_counts()
# Out:
# status
# Resolved            50131
# In_Progress         19783
# On_Hold             10165
# Closed_No_Action     9982
# Open                 9939
# Name: count, dtype: int64

# %%
df["priority"].value_counts()
# Out:
# priority
# Low       39735
# Medium    35313
# High      19865
# Urgent     5087
# Name: count, dtype: int64

# %%
df["resolution_time_hours"].mean()
# Out:
# np.float64(38.988940299999996)

# %%
df.groupby("priority")["resolution_time_hours"].mean()
# Out:
# priority
# High      30.896355
# Low       45.322063
# Medium    37.998652
# Urgent    27.996731
# Name: resolution_time_hours, dtype: float64

# %%
df["csat_score"].value_counts().sort_index()
# Out:
# csat_score
# 0    29941
# 1     5815
# 2    14871
# 3    20453
# 4    17321
# 5    11599
# Name: count, dtype: int64

# %%
df.groupby("csat_score")["resolution_time_hours"].mean()
# Out:
# csat_score
# 0    39.015745
# 1    39.243948
# 2    38.989488
# 3    39.082029
# 4    38.580635
# 5    39.236784
# Name: resolution_time_hours, dtype: float64

# %%
df["channel"].value_counts()
# Out:
# channel
# Phone_Transcript    20133
# Email               20088
# In_App              19982
# Web_Form            19965
# Chat                19832
# Name: count, dtype: int64

# %%
df["region"].value_counts()
# Out:
# region
# Mea        20151
# Unknown    19997
# Eu         19960
# Latam      19959
# Apac       19933
# Name: count, dtype: int64

# %%
df["product_area"].value_counts()
# Out:
# product_area
# Mobile_App             14432
# Login_Auth             14381
# Api_Integration        14350
# Billing                14289
# Data_Export            14262
# Analytics_Dashboard    14187
# Notifications          14099
# Name: count, dtype: int64

# %%
upper_limit = df["resolution_time_hours"].quantile(0.99)
df = df[df["resolution_time_hours"] <= upper_limit]

# %%
df["status"] = (
    df["status"]
    .str.strip()
    .str.replace("_", " ")
    .str.title()
)
# Out:
# /var/folders/22/9rlp1p9s37bbmyh4xc20j0_m0000gn/T/ipykernel_2405/1584510852.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["status"] = (

# %%
df["ticket_age_days"] = (
    pd.Timestamp.now() - df["created_at"]
).dt.days
# Out:
# /var/folders/22/9rlp1p9s37bbmyh4xc20j0_m0000gn/T/ipykernel_2405/2503189576.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["ticket_age_days"] = (

# %%
df["resolution_bucket"] = pd.cut(
    df["resolution_time_hours"],
    bins=[0, 12, 24, 48, 72, 168, 1000],
    labels=["<12h", "12–24h", "1–2 days", "2–3 days", "3–7 days", "7+ days"]
)
# Out:
# /var/folders/22/9rlp1p9s37bbmyh4xc20j0_m0000gn/T/ipykernel_2405/3962672078.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["resolution_bucket"] = pd.cut(

# %%
df["csat_percent"] = (df["csat_score"] / 5) * 100
# Out:
# /var/folders/22/9rlp1p9s37bbmyh4xc20j0_m0000gn/T/ipykernel_2405/1100461349.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["csat_percent"] = (df["csat_score"] / 5) * 100

# %%
top_regions = df["region"].value_counts().nlargest(5).index
df["region_grouped"] = df["region"].where(
    df["region"].isin(top_regions),
    "Other"
)
# Out:
# /var/folders/22/9rlp1p9s37bbmyh4xc20j0_m0000gn/T/ipykernel_2405/263570685.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["region_grouped"] = df["region"].where(

# %%
df["sla_breached"] = np.where(
    df["resolution_time_hours"] > 48,
    "Yes",
    "No"
)
# Out:
# /var/folders/22/9rlp1p9s37bbmyh4xc20j0_m0000gn/T/ipykernel_2405/2472659704.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["sla_breached"] = np.where(

# %%
df.sort_values("created_at", inplace=True)
# Out:
# /var/folders/22/9rlp1p9s37bbmyh4xc20j0_m0000gn/T/ipykernel_2405/513962174.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.sort_values("created_at", inplace=True)

# %%
df.rename(columns={
    "resolution_time_hours": "Resolution Time (Hours)",
    "csat_score": "CSAT Score",
    "customer_segment": "Customer Segment",
    "product_area": "Product Area"
}, inplace=True)
# Out:
# /var/folders/22/9rlp1p9s37bbmyh4xc20j0_m0000gn/T/ipykernel_2405/3737061259.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={

# %%
df.to_csv(
    "cleaned_it_support_tickets.csv",
    index=False
)
